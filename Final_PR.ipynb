# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/content/sample_data/used_car_price_dataset_extended final.csv')

# %%
data
# Out:
#       make_year  mileage_kmpl  engine_cc fuel_type  owner_count  price_usd  \
# 0          2001          8.17       4000    Petrol            4    8587.64
# 1          2014         17.59       1500    Petrol            4    5943.50
# 2          2023         18.09       2500    Diesel            5    9273.58
# 3          2009         11.28        800    Petrol            1    6836.24
# 4          2005         12.23       1000    Petrol            2    4625.79
# ...         ...           ...        ...       ...          ...        ...
# 9995       1996         15.25       1500    Petrol            2    5498.71
# 9996       1997         14.45       5000    Diesel            1    9588.31
# 9997       2002         19.41       1000    Diesel            4    4557.10
# 9998       2005         12.95       4000    Petrol            5    7413.59
# 9999       2007         18.81       5000    Petrol            1   11634.09
#
# ...

# %%
data.head()
# Out:
#    make_year  mileage_kmpl  engine_cc fuel_type  owner_count  price_usd  \
# 0       2001          8.17       4000    Petrol            4    8587.64
# 1       2014         17.59       1500    Petrol            4    5943.50
# 2       2023         18.09       2500    Diesel            5    9273.58
# 3       2009         11.28        800    Petrol            1    6836.24
# 4       2005         12.23       1000    Petrol            2    4625.79
#
#        brand transmission  color service_history  accidents_reported  \
# 0  Chevrolet       Manual  White             NaN                   0
# 1      Honda       Manual  Black             NaN                   0
# 2        BMW    Automatic  Black            Full                   1
# 3    Hyundai       Manual   Blue            Full                   0
# 4     Nissan    Automatic    Red            Full                   0
#
#   insurance_valid
# 0              No
# 1             Yes
# 2             Yes
# 3             Yes
# 4             Yes

# %%
data.shape
# Out:
# (10000, 12)

# %%
data.columns.tolist()
# Out:
# ['make_year',
#  'mileage_kmpl',
#  'engine_cc',
#  'fuel_type',
#  'owner_count',
#  'price_usd',
#  'brand',
#  'transmission',
#  'color',
#  'service_history',
#  'accidents_reported',
#  'insurance_valid']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   make_year           10000 non-null  int64
#  1   mileage_kmpl        10000 non-null  float64
#  2   engine_cc           10000 non-null  int64
#  3   fuel_type           10000 non-null  object
#  4   owner_count         10000 non-null  int64
#  5   price_usd           10000 non-null  float64
#  6   brand               10000 non-null  object
#  7   transmission        10000 non-null  object
#  8   color               10000 non-null  object
#  9   service_history     7962 non-null   object
#  10  accidents_reported  10000 non-null  int64
#  11  insurance_valid     10000 non-null  object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 937.6+ KB

# %%
data.describe(include='all')
# Out:
#            make_year  mileage_kmpl     engine_cc fuel_type   owner_count  \
# count   10000.000000  10000.000000  10000.000000     10000  10000.000000
# unique           NaN           NaN           NaN         3           NaN
# top              NaN           NaN           NaN    Petrol           NaN
# freq             NaN           NaN           NaN      4968           NaN
# mean     2009.206900     17.960753   2287.130000       NaN      3.003500
# std         8.373858      5.025486   1291.276927       NaN      1.418904
# min      1995.000000      5.000000    800.000000       NaN      1.000000
# 25%      2002.000000     14.540000   1200.000000       NaN      2.000000
# 50%      2009.000000     17.970000   1800.000000       NaN      3.000000
# 75%      2016.000000     21.352500   3000.000000       NaN      4.000000
# max      2023.000000     35.000000   5000.000000       NaN      5.000000
#
#            price_usd   brand transmission  color service_history  \
# ...

# %%
import missingno as msno
msno.bar(data)
plt.show()

# %%
#clean Missing Value
data.fillna({'engine_cc':data['engine_cc'].mean(),'fuel_type':'Unknown'},inplace=True)

# %%
#Explore Categorical Columns

categorical_cols=data.select_dtypes(include='object').columns
for col in categorical_cols:
  print(f"{col} - Unique: {data[col].nunique()},sample values:{data[col].unique()[:5]}")
# Out:
# fuel_type - Unique: 3,sample values:['Petrol' 'Diesel' 'Electric']
# brand - Unique: 10,sample values:['Chevrolet' 'Honda' 'BMW' 'Hyundai' 'Nissan']
# transmission - Unique: 2,sample values:['Manual' 'Automatic']
# color - Unique: 6,sample values:['White' 'Black' 'Blue' 'Red' 'Gray']
# service_history - Unique: 2,sample values:[nan 'Full' 'Partial']
# insurance_valid - Unique: 2,sample values:['No' 'Yes']

# %%
plt.figure(figsize=(10,5))
sns.histplot(data['price_usd'])
# Out:
# <Axes: xlabel='price_usd', ylabel='Count'>

# %%
#Visualize Price Distribution
plt.figure(figsize= (10,5))
sns.histplot(data['price_usd'],kde=True,bins=50)
plt.title("Car Price Distribution")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %%
#Correlation Analysi
numeric_cols = data.select_dtypes(include=np.number).columns
plt.figure(figsize=(12,8))
sns.heatmap(data[numeric_cols].corr(),annot=True,fmt=".2f",cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
# box plot chart add karna hai

# %%
# Reset index so 'brand' becomes a column
summary_reset = summary.reset_index()

# Create a scatter plot with regression line
plt.figure(figsize=(10, 6))
sns.regplot(data=summary_reset, x='avg_mileage', y='avg_price', scatter=True, fit_reg=True)

for i in range(len(summary_reset)):
    plt.text(summary_reset['avg_mileage'][i], summary_reset['avg_price'][i],
             summary_reset['brand'][i], fontsize=8, alpha=0.7)

plt.title("Average Price vs. Average Mileage by Brand")
plt.xlabel("Average Mileage (km/l)")
plt.ylabel("Average Price (USD)")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-16-41839592.py in <cell line: 0>()
#       1 # Reset index so 'brand' becomes a column
# ----> 2 summary_reset = summary.reset_index()
#       3
#       4 # Create a scatter plot with regression line
#       5 plt.figure(figsize=(10, 6))
#
# NameError: name 'summary' is not defined

# %%
# Save Cleaned Datase
data.to_csv("used_car_cleaned.csv", index=False)

# %%
data

# %%
# Ensure columns are numeric
brand_counts['make_year'] = pd.to_numeric(brand_counts['make_year'], errors='coerce')
brand_counts['brand_count'] = pd.to_numeric(brand_counts['brand_count'], errors='coerce')

# Plot with regression line (ML-inspired look)
plt.figure(figsize=(10, 6))
sns.regplot(
    data=brand_counts,
    x='make_year',
    y='brand_count',
    marker='o',
    line_kws={'color': 'crimson', 'label': 'Trend Line'}
)

# Annotate peak year
plt.axvline(x=peak_year['make_year'], color='gray', linestyle='--', alpha=0.6)
plt.text(
    x=peak_year['make_year'],
    y=peak_year['brand_count'] + 1,
    s=f"Peak Year: {int(peak_year['make_year'])}",
    color='darkblue'
)

plt.title('Trend of Car Brand Launches Over Time')
plt.xlabel('Launch Year')
plt.ylabel('Unique Brands Launched')
plt.legend()
plt.grid(True)
# plt.tight_layout()
plt.show()

# %%
car_counts = data.groupby('make_year').size().reset_index(name='car_count')

plt.figure(figsize=(10, 6))
plt.plot(car_counts['make_year'], car_counts['car_count'], marker='s', linestyle='-', color='teal')
plt.title('Total Number of Cars Manufactured per Year')
plt.xlabel('Make Year')
plt.ylabel('Number of Cars')
plt.grid(True)
plt.tight_layout()
plt.show()
